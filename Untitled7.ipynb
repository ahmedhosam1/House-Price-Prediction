# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn import linear_model

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("Documents\house.csv")

# %%
data
# Out:
#      Neighborhood  OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  \
# 0         CollgCr            7       2003          2003          856
# 1         Veenker            6       1976          1976         1262
# 2         CollgCr            7       2001          2002          920
# 3         Crawfor            7       1915          1970          756
# 4         NoRidge            8       2000          2000         1145
# ...           ...          ...        ...           ...          ...
# 1455      Gilbert            6       1999          2000          953
# 1456       NWAmes            6       1978          1988         1542
# 1457      Crawfor            7       1941          2006         1152
# 1458        NAmes            5       1950          1996         1078
# 1459      Edwards            5       1965          1965         1256
#
#      CentralAir  GrLivArea  BedroomAbvGr KitchenQual  TotRmsAbvGrd  \
# 0             Y       1710             3          Gd             8
# 1             Y       1262             3          TA             6
# 2             Y       1786             3          Gd             6
# 3             Y       1717             3          Gd             7
# 4             Y       2198             4          Gd             9
# ...         ...        ...           ...         ...           ...
# 1455          Y       1647             3          TA             7
# 1456          Y       2073             3          TA             7
# 1457          Y       2340             4          Gd             9
# 1458          Y       1078             2          Gd             5
# 1459          Y       1256             3          TA             6
#
#       Fireplaces  GarageCars  GarageArea  SalePrice
# 0              0           2         548     208500
# 1              1           2         460     181500
# 2              1           2         608     223500
# 3              1           3         642     140000
# 4              1           3         836     250000
# ...          ...         ...         ...        ...
# 1455           1           2         460     175000
# 1456           2           2         500     210000
# 1457           2           1         252     266500
# 1458           0           1         240     142125
# 1459           0           1         276     147500
#
# [1460 rows x 14 columns]

# %%
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.scatter(data.GrLivArea,data.SalePrice,color='red',marker='+',)
plt.show()

# %%
data.GrLivArea.min()
# Out:
# 334

# %%
data.GrLivArea.max()
# Out:
# 5642

# %%
Feature = data.drop(['SalePrice','CentralAir','KitchenQual','Neighborhood'] ,axis='columns')
Feature
# Out:
#       OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  GrLivArea  \
# 0               7       2003          2003          856       1710
# 1               6       1976          1976         1262       1262
# 2               7       2001          2002          920       1786
# 3               7       1915          1970          756       1717
# 4               8       2000          2000         1145       2198
# ...           ...        ...           ...          ...        ...
# 1455            6       1999          2000          953       1647
# 1456            6       1978          1988         1542       2073
# 1457            7       1941          2006         1152       2340
# 1458            5       1950          1996         1078       1078
# 1459            5       1965          1965         1256       1256
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars  GarageArea
# 0                3             8           0           2         548
# 1                3             6           1           2         460
# 2                3             6           1           2         608
# 3                3             7           1           3         642
# 4                4             9           1           3         836
# ...            ...           ...         ...         ...         ...
# 1455             3             7           1           2         460
# 1456             3             7           2           2         500
# 1457             4             9           2           1         252
# 1458             2             5           0           1         240
# 1459             3             6           0           1         276
#
# [1460 rows x 10 columns]

# %%
price = data.SalePrice
price
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
model = linear_model.LinearRegression()
model.fit (Feature,price)
# Out:
# LinearRegression()

# %%
model.predict([[7, 2003, 2003, 856, 2000, 4, 8, 1, 2, 600]])
# Out:
# array([230584.76914424])

# %%
# Out:
#   Cell In[45], line 1
#     jupyter nbconvert --to script my_notebook.ipynb
#             ^
# SyntaxError: invalid syntax
